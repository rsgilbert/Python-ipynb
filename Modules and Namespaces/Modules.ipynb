# %%
# What is a module

# %%
def fun():
    pass

# %%
fun
# Out:
# <function __main__.fun>

# %%
# where is fun located

# %%
id(fun)
# Out:
# 140260281993688

# %%
# looking at namespace

# %%
# globals(): tells us all the global objects in our namespace
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# looking at namespace',
#   '# globals: tells us all the global objects in our namespace\nglobals()',
#   '# globals(): tells us all the global objects in our namespace\nglobals()',
#   'globals[In][2]',
#   'globals()[In][2]',
#   'globals()[In]',
#   'globals()',
#   'globals().get(In)',
#   'type(globals())',
#   '[ print(i) for i in globals()]',
#   '[ print(i, j) for i, j in globals().items()]',
#   "globals()['In']",
#   "globals()['fun']",
#   'def fun():\n    pass',
#   'fun',
#   '# where is fun located',
#   'id(fun)',
#   '# looking at namespace',
#   '# globals(): tells us all the global objects in our namespace\nglobals()'],
#  '_oh': {2: {...},
#   3: {...},
#   7: {...},
# ...

# %%
[ print(i, j) for i, j in globals().items()]
# Out:
# __name__ __main__
# __doc__ Automatically created module for IPython interactive environment
# __package__ None
# __loader__ None
# __spec__ None
# __builtin__ <module 'builtins' (built-in)>
# __builtins__ <module 'builtins' (built-in)>
# _ih ['', '# looking at namespace', '# globals: tells us all the global objects in our namespace\nglobals()', '# globals(): tells us all the global objects in our namespace\nglobals()', 'globals[In][2]', 'globals()[In][2]', 'globals()[In]', 'globals()', 'globals().get(In)', 'type(globals())', '[ print(i) for i in globals()]', '[ print(i, j) for i, j in globals().items()]', "globals()['In']", "globals()['fun']", 'def fun():\n    pass', 'fun', '# where is fun located', 'id(fun)', '# looking at namespace', '# globals(): tells us all the global objects in our namespace\nglobals()', '[ print(i, j) for i, j in globals().items()]']
# ...

# %%
globals()['In']
# Out:
# ['',
#  '# looking at namespace',
#  '# globals: tells us all the global objects in our namespace\nglobals()',
#  '# globals(): tells us all the global objects in our namespace\nglobals()',
#  'globals[In][2]',
#  'globals()[In][2]',
#  'globals()[In]',
#  'globals()',
#  'globals().get(In)',
#  'type(globals())',
#  '[ print(i) for i in globals()]',
#  '[ print(i, j) for i, j in globals().items()]',
#  "globals()['In']",
#  "globals()['fun']",
#  'def fun():\n    pass',
#  'fun',
#  '# where is fun located',
#  'id(fun)',
#  '# looking at namespace',
#  '# globals(): tells us all the global objects in our namespace\nglobals()',
#  '[ print(i, j) for i, j in globals().items()]',
#  "globals()['In']"]

# %%
globals()['fun']
# Out:
# <function __main__.fun>

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# looking at namespace',
#   '# globals: tells us all the global objects in our namespace\nglobals()',
#   '# globals(): tells us all the global objects in our namespace\nglobals()',
#   'globals[In][2]',
#   'globals()[In][2]',
#   'globals()[In]',
#   'globals()',
#   'globals().get(In)',
#   'type(globals())',
#   '[ print(i) for i in globals()]',
#   '[ print(i, j) for i, j in globals().items()]',
#   "globals()['In']",
#   "globals()['fun']",
#   'def fun():\n    pass',
#   'fun',
#   '# where is fun located',
#   'id(fun)',
#   '# looking at namespace',
#   '# globals(): tells us all the global objects in our namespace\nglobals()',
#   '[ print(i, j) for i, j in globals().items()]',
# ...

# %%
# we are in the local scope
locals() is globals()
# Out:
# True

# %%
def bull():
    a = 10 
    global b
    b = 9
    print(locals())

# %%
bull()
# Out:
# {'a': 10}

# %%
import math

# %%
math
# Out:
# <module 'math' (built-in)>

# %%
import decimal

# %%
decimal
# Out:
# <module 'decimal' from '/usr/lib/python3.7/decimal.py'>

# %%
#  globals() : globals now contains math

# %%
id(math)
# Out:
# 140260380382696

# %%
import math # same id
id(math)
# Out:
# 140718457927144

# %%
import sys

# %%
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'posix': <module 'posix' (built-in)>,
#  'encodings': <module 'encodings' from '/usr/lib/python3.7/encodings/__init__.py'>,
#  'codecs': <module 'codecs' from '/usr/lib/python3.7/codecs.py'>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'encodings.aliases': <module 'encodings.aliases' from '/usr/lib/python3.7/encodings/aliases.py'>,
#  'encodings.utf_8': <module 'encodings.utf_8' from '/usr/lib/python3.7/encodings/utf_8.py'>,
# ...

# %%
type(sys.modules)
# Out:
# dict

# %%
sys.modules['math']
# Out:
# <module 'math' (built-in)>

# %%
math.__name__
# Out:
# 'math'

# %%
math.__dict__
# Out:
# {'__name__': 'math',
#  '__doc__': 'This module is always available.  It provides access to the\nmathematical functions defined by the C standard.',
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='math', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#  'acos': <function math.acos>,
#  'acosh': <function math.acosh>,
#  'asin': <function math.asin>,
#  'asinh': <function math.asinh>,
#  'atan': <function math.atan>,
#  'atan2': <function math.atan2>,
#  'atanh': <function math.atanh>,
#  'ceil': <function math.ceil>,
#  'copysign': <function math.copysign>,
#  'cos': <function math.cos>,
#  'cosh': <function math.cosh>,
#  'degrees': <function math.degrees>,
#  'erf': <function math.erf>,
#  'erfc': <function math.erfc>,
#  'exp': <function math.exp>,
#  'expm1': <function math.expm1>,
#  'fabs': <function math.fabs>,
#  'factorial': <function math.factorial>,
#  'floor': <function math.floor>,
# ...

# %%
f = math.__dict__['sqrt']

# %%
f(2)
# Out:
# 1.4142135623730951

# %%
import fractions

# %%
sys.modules['fractions']
# Out:
# <module 'fractions' from '/usr/lib/python3.7/fractions.py'>

# %%
dir(fractions)
# Out:
# ['Decimal',
#  'Fraction',
#  '_PyHASH_INF',
#  '_PyHASH_MODULUS',
#  '_RATIONAL_FORMAT',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_gcd',
#  'gcd',
#  'math',
#  'numbers',
#  'operator',
#  're',
#  'sys']

# %%
fractions.__dict__
# Out:
# {'__name__': 'fractions',
#  '__doc__': 'Fraction, infinite-precision, real numbers.',
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7ffb8c58fc50>,
#  '__spec__': ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ffb8c58fc50>, origin='/usr/lib/python3.7/fractions.py'),
#  '__file__': '/usr/lib/python3.7/fractions.py',
#  '__cached__': '/usr/lib/python3.7/__pycache__/fractions.cpython-37.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   '__build_class__': <function __build_class__>,
#   '__import__': <function __import__>,
#   'abs': <function abs>,
#   'all': <function all>,
# ...

# %%
import types

# %%
isinstance(fractions, types.ModuleType)
# Out:
# True

# %%
isinstance(int, types.ModuleType)
# Out:
# False

# %%
types.ModuleType.__dict__
# Out:
# mappingproxy({'__repr__': <slot wrapper '__repr__' of 'module' objects>,
#               '__getattribute__': <slot wrapper '__getattribute__' of 'module' objects>,
#               '__setattr__': <slot wrapper '__setattr__' of 'module' objects>,
#               '__delattr__': <slot wrapper '__delattr__' of 'module' objects>,
#               '__init__': <slot wrapper '__init__' of 'module' objects>,
#               '__new__': <function module.__new__>,
#               '__dir__': <method '__dir__' of 'module' objects>,
#               '__dict__': <member '__dict__' of 'module' objects>,
#               '__doc__': 'Create a module object.\n\nThe name must be a string; the optional doc argument can have any type.'})

# %%
fractions.__spec__
# Out:
# ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ffb8c58fc50>, origin='/usr/lib/python3.7/fractions.py')

# %%
'__name__' in fractions.__dict__
# Out:
# True

# %%
'__doc__' in dir(fractions)
# Out:
# True

# %%
myModule = types.ModuleType('mymy', ' this is my module')

# %%
isinstance(myModule, types.ModuleType)
# Out:
# True

# %%
myModule.__dict__
# Out:
# {'__name__': 'mymy',
#  '__doc__': ' this is my module',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None}

# %%
myModule.beloved ="Gloria"

# %%
myModule.__dict__
# Out:
# {'__name__': 'mymy',
#  '__doc__': ' this is my module',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  'beloved': 'Gloria'}

# %%
fractions.__name__
# Out:
# 'fractions'

# %%
myModule.tell = lambda : myModule.beloved

# %%
myModule.tell()
# Out:
# 'Gloria'

# %%
'tell'in globals()
# Out:
# False

# %%
tell = myModule.tell

# %%
tell()
# Out:
# 'Gloria'

# %%
'tell' in globals()
# Out:
# True

# %%
dir(myModule)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'beloved',
#  'tell']

# %%
t = getattr(myModule, 'tell')

# %%
t()
# Out:
# 'Gloria'
